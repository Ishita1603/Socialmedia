# %%
import pandas as pd
file=pd.read_excel('C:\\Users\\asus\\Documents\\SocialMedia/Twitter.xlsx')
file
# Out:
#                    Date  Tweets published  impressions  engagements  \
# 0            2020-01-01                 0         8961          238
# 1            2020-01-02                 5        14964          694
# 2            2020-01-03                 0         8749          241
# 3            2020-01-04                 1         8394          158
# 4            2020-01-05                 1         7060          165
# 5            2020-01-06                 3        11122          471
# 6            2020-01-07                 4        14861          497
# 7            2020-01-08                 2        10818          251
# 8            2020-01-09                 4        11725          412
# 9            2020-01-10                 1         7248          166
# 10           2020-01-11                 1         7239          154
# 11           2020-01-12                 4         9925          254
# 12           2020-01-13                 1         7936          195
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
file.rename(columns={'Tweets published':'tweets_published'},inplace=True)
file.head(5)
# Out:
#          Date  tweets_published  impressions  engagements  engagement rate  \
# 0  2020-01-01                 0         8961          238         0.026560
# 1  2020-01-02                 5        14964          694         0.046378
# 2  2020-01-03                 0         8749          241         0.027546
# 3  2020-01-04                 1         8394          158         0.018823
# 4  2020-01-05                 1         7060          165         0.023371
#
#    retweets  replies  likes  user profile clicks  url clicks  hashtag clicks  \
# 0         9        3     83                   24           7               0
# 1        17        2    150                   50          28               3
# 2         2        0     35                    8          11               1
# 3         5        0     29                    7          10               0
# 4        10        0     40                   13          10               0
#
# ...

# %%
#this shows all the values
plt.scatter(file.tweets_published, file.likes,  color='blue')
plt.xlabel("No. of tweets")
plt.ylabel("No. of likes")
plt.show()

# %%
#this shows the max value
plt.bar(file.tweets_published, file.likes,  color='blue')
plt.xlabel("No. of tweets")
plt.ylabel("No. of likes")
plt.show()

# %%
plt.scatter(file.tweets_published, file.engagements,  color='blue')
plt.xlabel("No. of tweets")
plt.ylabel("No. of likes")
plt.show()

# %%
plt.scatter(file.impressions, file.engagements,  color='blue')
plt.xlabel("No. of impressions")
plt.ylabel("No. of engagements")
plt.show()

# %%
plt.scatter(file.engagements, file.likes, color='blue')
plt.xlabel("No. of engagements")
plt.ylabel("No. of likes")
plt.show()

# %%
file.rename(columns={'engagement rate':'engagement_rate'},inplace=True)
file.head(5)
# Out:
#          Date  tweets_published  impressions  engagements  engagement_rate  \
# 0  2020-01-01                 0         8961          238         0.026560
# 1  2020-01-02                 5        14964          694         0.046378
# 2  2020-01-03                 0         8749          241         0.027546
# 3  2020-01-04                 1         8394          158         0.018823
# 4  2020-01-05                 1         7060          165         0.023371
#
#    retweets  replies  likes  user profile clicks  url clicks  hashtag clicks  \
# 0         9        3     83                   24           7               0
# 1        17        2    150                   50          28               3
# 2         2        0     35                    8          11               1
# 3         5        0     29                    7          10               0
# 4        10        0     40                   13          10               0
#
# ...

# %%
plt.scatter(file.engagement_rate, file.likes, color='blue')
plt.xlabel("engagement_rate")
plt.ylabel("No. of likes")
plt.show()
